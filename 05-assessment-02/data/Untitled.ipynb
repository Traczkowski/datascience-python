# %%
import pandas as pd

# %%
df = pd.read_csv('./rent.csv')

# %%
df.head()
# Out:
#         Neighborhood         City State  med_2011  med_2014
# 0   Northeast Dallas       Dallas    TX     825.0     985.0
# 1           Paradise    Las Vegas    NV     900.0    1100.0
# 2           Maryvale      Phoenix    AZ     795.0     850.0
# 3    Upper West Side     New York    NY    2795.0    3300.0
# 4  South Los Angeles  Los Angeles    CA    1150.0    1400.0

# %%
df['med_2011'].max()
# Out:
# 65000.0

# %%
df.groupby(['City', 'State'])['med_2011', 'med_2014'].max()
# Out:
#                          med_2011  med_2014
# City              State
# Akron             OH        690.0     725.0
# Albany            NY          NaN     952.0
# Albuquerque       NM       1099.0    1150.0
# Alexandria        VA       2155.0    2250.0
# Amherst           MA          NaN       NaN
# Anaheim           CA       2005.0    2245.0
# Anchorage         AK          NaN    1995.0
# Arlington         TX       1100.0    1300.0
#                   VA       2800.0    2796.0
# Atlanta           GA       2000.0    2450.0
# Auburn            WA       1045.0    1375.0
# Augusta           GA        826.0     955.0
# Aurora            CO       1350.0    1400.0
# Austin            TX       1799.0    2800.0
# Bakersfield       CA          NaN    1550.0
# Baltimore         MD       2100.0    2210.0
# Beaverton         OR        925.0    1167.0
# Bellevue          WA       2290.0    2550.0
# Bellingham        WA        879.0     710.0
# Bend              OR          NaN    1200.0
# ...
