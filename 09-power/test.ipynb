# %%
# %load_ext autoreload
# %autoreload 2

# %%
import main as m

# %%
m.add(3,5)
# Out:
# 243

# %%
e = m.Experiment(50, 6)

# %%
e

# %%
e.__dict__
# Out:
# {'mean': 3.6366666666666663,
#  'n': 50,
#  'rolls': 6,
#  'sample_means': [3.0,
#   3.3333333333333335,
#   3.5,
#   3.6666666666666665,
#   3.6666666666666665,
#   2.8333333333333335,
#   3.0,
#   2.6666666666666665,
#   4.0,
#   5.333333333333333,
#   3.5,
#   5.0,
#   3.6666666666666665,
#   4.0,
#   3.6666666666666665,
#   4.166666666666667,
#   3.1666666666666665,
#   3.5,
#   3.1666666666666665,
#   4.0,
#   2.0,
#   2.8333333333333335,
#   1.6666666666666667,
#   4.166666666666667,
#   3.6666666666666665,
#   4.5,
#   4.166666666666667,
#   2.3333333333333335,
#   2.6666666666666665,
#   3.6666666666666665,
#   4.0,
#   3.0,
#   4.333333333333333,
#   3.3333333333333335,
#   4.333333333333333,
#   4.666666666666667,
#   4.166666666666667,
#   3.1666666666666665,
#   3.3333333333333335,
#   3.6666666666666665,
#   2.8333333333333335,
#   4.333333333333333,
#   3.3333333333333335,
#   4.5,
#   3.3333333333333335,
#   4.0,
#   4.5,
#   4.166666666666667,
#   4.666666666666667,
# ...
